# %%
#pandas
import pandas as pd
#Meatplotlib
import matplotlib.pyplot as plt
#seaborn
import seaborn as sns
#numpy

import numpy as np
#sklearn
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as knn
import pickle

# %%
#sending Data Set
crop_of = pd.read_csv("Crop_recommendation.csv")
crop_of.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
crop_of.shape
# Out:
# (2200, 8)

# %%
##Check Null values are there or not
crop_of.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
crop_of.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Nitrogen
plt.figure(figsize=(8, 7))
sns.histplot(x='N', data=crop_of, color='b')
plt.title("Nitrogen for crops", fontsize=28)

# Potassium
plt.figure(figsize=(8, 7))
sns.histplot(x='K', data=crop_of, color='b')
plt.title("Potassium for crops", fontsize=28)

# Phosphorus
plt.figure(figsize=(8, 7))
sns.histplot(x='P', data=crop_of, color='b')
plt.title("Phosphorus for crops", fontsize=28)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Temperature
plt.figure(figsize=(10, 6))
sns.boxplot(x='temperature', data=crop_of)
plt.title("Temperature for crops", fontsize=20)

# Humidity
plt.figure(figsize=(10, 6))
sns.boxplot(x='humidity', data=crop_of)
plt.title("Humidity for crops", fontsize=20)

# pH
plt.figure(figsize=(8, 7))
sns.histplot(x='ph', data=crop_of, color='b')
plt.title("PH for crops", fontsize=20)

# Rainfall
plt.figure(figsize=(8, 7))
sns.histplot(x='rainfall', data=crop_of, color='b')
plt.title("Rainfall feature", fontsize=28)

plt.show()

# %%
sns.distplot(crop_of['ph'])
# Out:
# C:\Users\kapil\AppData\Local\Temp\ipykernel_9992\232839206.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crop_of['ph'])
# <Axes: xlabel='ph', ylabel='Density'>

# %%
sns.scatterplot(x=crop_of["temperature"], y=crop_of["label"])
# Out:
# <Axes: xlabel='temperature', ylabel='label'>

# %%
sns.FacetGrid (crop_of, hue="label").map(plt.scatter, "N", "humidity").add_legend()
# Out:
# c:\Users\kapil\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
crop_of.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
crop_of['label'].unique
# Out:
# <bound method Series.unique of 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object>

# %%
crop_of[crop_of=='rice']
# Out:
#        N   P   K  temperature  humidity  ph  rainfall label
# 0    NaN NaN NaN          NaN       NaN NaN       NaN  rice
# 1    NaN NaN NaN          NaN       NaN NaN       NaN  rice
# 2    NaN NaN NaN          NaN       NaN NaN       NaN  rice
# 3    NaN NaN NaN          NaN       NaN NaN       NaN  rice
# 4    NaN NaN NaN          NaN       NaN NaN       NaN  rice
# ...   ..  ..  ..          ...       ...  ..       ...   ...
# 2195 NaN NaN NaN          NaN       NaN NaN       NaN   NaN
# 2196 NaN NaN NaN          NaN       NaN NaN       NaN   NaN
# 2197 NaN NaN NaN          NaN       NaN NaN       NaN   NaN
# 2198 NaN NaN NaN          NaN       NaN NaN       NaN   NaN
# 2199 NaN NaN NaN          NaN       NaN NaN       NaN   NaN
#
# [2200 rows x 8 columns]

# %%
crop_of['label'].unique
# Out:
# <bound method Series.unique of 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object>

# %%
#plot heat map
# Dummy data
data = {'feature1': np.random.rand(100),
        'feature2': np.random.rand(100),
        'feature3': np.random.rand(100)}
crop_of = pd.DataFrame(data)

# Define top_corr_features
top_corr_features = ['feature1', 'feature2', 'feature3']

# Generate the heatmap
g = sns.heatmap(crop_of[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# %%
sns.pairplot (crop_of,hue="label",size=3)
# Out:
# c:\Users\kapil\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# c:\Users\kapil\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
X = crop_of.drop(['label', 'label'], axis=1)
y= pd.Categorical (crop_of.label)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
# K-Nearest-Neighbors Classifier
knnclassifier=knn (n_neighbors=9)
knnclassifier.fit(X_train, y_train)
training_score = knnclassifier.score(X_train, y_train)
testing_score = knnclassifier.score(X_test, y_test)
print("The accuracy of K Nearest Neighbors Classifier is", training_score, testing_score)
#print("The accuracy of K Nearest Neighbors Classifier is",
      #knnclassifier.score (X_train, y_train), knnclassifier.score (X_test,y_test))
#knn [knnclassifier.score (X_train, y_train), knnclassifier. score (X_test,y_test)]
# Out:
# The accuracy of K Nearest Neighbors Classifier is 0.9835227272727273 0.9886363636363636

# %%
# Support Vector Machines Classifier
svm = SVC()
svm.fit(X_train, y_train)
print("The accuracy of SVM is",
      svm.score (X_train,y_train), svm.score (X_test,y_test))
svm = [svm.score (X_train, y_train), svm.score (X_test,y_test)]
# Out:
# The accuracy of SVM is 0.9767045454545454 0.9863636363636363

# %%
#Decision Tree Classifier Model
dtclassifier = DecisionTreeClassifier(max_depth=7)
dtclassifier.fit(X_train,y_train)
training_score = dtclassifier.score(X_train, y_train)
testing_score = dtclassifier.score(X_test, y_test)
print("The accuracy of Decision Tree Classifier is",
       dtclassifier.score (X_train,y_train), dtclassifier.score (X_test,y_test))
#dt = dt [dtclassifier.score (X_train, y_train), dtclassifier.score (X_test,y_test)]
# Out:
# The accuracy of Decision Tree Classifier is 0.7363636363636363 0.6477272727272727

# %%
#Random Forest Classifier Model
rfclassifier = RandomForestClassifier()
rfclassifier.fit(X_train, y_train)
print("The accuracy of random forest Classifier is",
      rfclassifier.score (X_train, y_train), rfclassifier.score (X_test,y_test))
rf = [rfclassifier.score (X_train,y_train), rfclassifier.score (X_test,y_test)]
# Out:
# The accuracy of random forest Classifier is 1.0 0.9954545454545455

# %%
from sklearn.tree import DecisionTreeClassifier

# Create and fit the Decision Tree classifier
dtclassifier = DecisionTreeClassifier(max_depth=7)
dtclassifier.fit(X_train, y_train)

# Calculate and print the accuracy on the training and testing sets
training_score = dtclassifier.score(X_train, y_train)
testing_score = dtclassifier.score(X_test, y_test)

print("The accuracy of Decision Tree Classifier is", training_score, testing_score)

# Store the scores in a list
dt = [training_score, testing_score]
# Out:
# The accuracy of Decision Tree Classifier is 0.7363636363636363 0.6477272727272727

# %%
dtclassifier =DecisionTreeClassifier()
dtclassifier.fit(X_train,y_train)

y_pred =dtclassifier.predict(X_test)

print(classification_report (y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        24
#       banana       1.00      1.00      1.00        18
#    blackgram       1.00      1.00      1.00        20
#     chickpea       1.00      1.00      1.00        25
#      coconut       1.00      1.00      1.00        10
#       coffee       1.00      1.00      1.00        14
#       cotton       1.00      1.00      1.00        23
#       grapes       1.00      1.00      1.00        21
#         jute       1.00      1.00      1.00        16
#  kidneybeans       1.00      1.00      1.00        22
#       lentil       1.00      1.00      1.00        16
#        maize       1.00      1.00      1.00        22
#        mango       1.00      1.00      1.00        21
#    mothbeans       1.00      1.00      1.00        16
#     mungbean       1.00      1.00      1.00        24
#    muskmelon       1.00      1.00      1.00        16
# ...

# %%
rfclassifier=RandomForestClassifier()
rfclassifier.fit(X_train,y_train)

y_pred =rfclassifier.predict(X_test)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        17
#       banana       1.00      1.00      1.00        16
#    blackgram       1.00      1.00      1.00        20
#     chickpea       1.00      1.00      1.00        22
#      coconut       1.00      1.00      1.00        16
#       coffee       1.00      1.00      1.00        20
#       cotton       1.00      1.00      1.00        29
#       grapes       1.00      1.00      1.00        24
#         jute       0.95      1.00      0.97        18
#  kidneybeans       1.00      1.00      1.00        17
#       lentil       1.00      0.94      0.97        17
#        maize       1.00      1.00      1.00        22
#        mango       1.00      1.00      1.00        17
#    mothbeans       0.96      1.00      0.98        27
#     mungbean       1.00      1.00      1.00        20
#    muskmelon       1.00      1.00      1.00        17
# ...

# %%
# open a file, where you want to store the data
pickle.dump(knnclassifier, open('model.pkl', 'wb'))
